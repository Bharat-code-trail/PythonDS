# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('/content/drive/MyDrive/Data Science Project /Orange Quality Data.csv')

# %% [markdown]
# ## Basic Analysis

# %%
df.head()
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
#
#    HarvestTime (days)  Ripeness (1-5)         Color       Variety  \
# 0                  10             4.0        Orange      Valencia
# 1                  14             4.5   Deep Orange         Navel
# 2                   7             5.0  Light Orange     Cara Cara
# 3                  21             3.5    Orange-Red  Blood Orange
# 4                  12             5.0        Orange        Hamlin
#
#   Blemishes (Y/N)  Quality (1-5)
# 0               N            4.0
# 1               N            4.5
# ...

# %%
df.tail()
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
#      HarvestTime (days)  Ripeness (1-5)         Color            Variety  \
# 236                  13             1.0    Orange-Red          Tangerine
# 237                  20             5.0  Light Orange  Minneola (Hybrid)
# 238                  13             3.0   Deep Orange             Temple
# 239                  23             1.0  Light Orange       Moro (Blood)
# 240                  21             2.0    Orange-Red              Jaffa
#
#              Blemishes (Y/N)  Quality (1-5)
# ...

# %%
df.describe()
# Out:
#         Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# count  241.000000  241.000000        241.000000    241.000000      241.000000
# mean     7.844813  205.128631         10.907884      3.473900        3.072614
# std      1.086002   56.461012          2.760446      0.421007        1.323630
# min      6.000000  100.000000          5.500000      2.800000        1.000000
# 25%      6.900000  155.000000          8.500000      3.200000        2.000000
# 50%      7.800000  205.000000         11.000000      3.400000        3.000000
# 75%      8.700000  252.000000         13.400000      3.800000        4.000000
# max     10.000000  300.000000         16.000000      4.400000        5.000000
#
#        HarvestTime (days)  Ripeness (1-5)  Quality (1-5)
# count          241.000000      241.000000     241.000000
# mean            15.344398        3.599585       3.817427
# std              5.323852        1.205214       1.014410
# ...

# %%
df.shape
# Out:
# (241, 11)

# %%
df.columns
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Size (cm)             0
# Weight (g)            0
# Brix (Sweetness)      0
# pH (Acidity)          0
# Softness (1-5)        0
# HarvestTime (days)    0
# Ripeness (1-5)        0
# Color                 0
# Variety               0
# Blemishes (Y/N)       0
# Quality (1-5)         0
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.palplot(sns.color_palette("flare", 10))

# %%
df.head(2)
df.columns
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
sns.barplot(x='Quality (1-5)', y='pH (Acidity)', data=df)
# Out:
# <Axes: xlabel='Quality (1-5)', ylabel='pH (Acidity)'>

# %%
sns.lineplot(x='Size (cm)', y='Weight (g)', data=df)
# Out:
# <Axes: xlabel='Size (cm)', ylabel='Weight (g)'>

# %%
sns.scatterplot(x='Size (cm)', y='HarvestTime (days)',hue='Color', data=df)
# Out:
# <Axes: xlabel='Size (cm)', ylabel='HarvestTime (days)'>

# %% [markdown]
# ### 1) Is there a correlation between the size (Size (cm)) and the weight (Weight (g)) of the fruit?

# %%
co = df['Size (cm)'].corr(df['Weight (g)'])
co
# Out:
# np.float64(0.30534816456201685)

# %%
sns.heatmap(df[['Size (cm)','Weight (g)']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### 2) How does the sweetness (Brix) of the fruit correlate with its acidity (pH)? Do sweeter fruits have lower acidity?

# %%
cor = df['Brix (Sweetness)'].corr(df['pH (Acidity)'])
cor
# Out:
# np.float64(-0.30007995138340415)

# %%
sns.heatmap(df[['Brix (Sweetness)', 'pH (Acidity)']].corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ### 3) How does the softness (Softness (1-5)) of the fruit relate to its ripeness (Ripeness (1-5))?

# %%
sns.lineplot(x='Softness (1-5)', y='Ripeness (1-5)', data=df)
# Out:
# <Axes: xlabel='Softness (1-5)', ylabel='Ripeness (1-5)'>

# %% [markdown]
# ### 4) Do fruits with blemishes (Blemishes (Y/N)) tend to have lower ripeness or softness levels?

# %%
b = df.groupby('Blemishes (Y/N)')[['Ripeness (1-5)', 'Softness (1-5)']].mean()
b
# Out:
#                          Ripeness (1-5)  Softness (1-5)
# Blemishes (Y/N)
# N                              3.906040        2.986577
# N (Minor)                      4.000000        4.000000
# N (Split Skin)                 2.000000        5.000000
# Y (Bruise)                     3.500000        3.500000
# Y (Bruising)                   3.333333        3.388889
# Y (Minor Insect Damage)        2.750000        2.916667
# Y (Minor)                      3.357143        2.178571
# Y (Mold Spot)                  3.150000        4.000000
# Y (Scars)                      3.235294        3.382353
# Y (Split Skin)                 3.125000        3.375000
# Y (Sunburn Patch)              2.913043        3.086957
# Y (Sunburn)                    2.000000        4.500000

# %% [markdown]
# ### 5) How do different fruit varieties (Variety) differ in terms of size, weight, sweetness, acidity, and ripeness?

# %%
df.columns
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
d = df.groupby('Variety')[['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)', 'Ripeness (1-5)']].max()
d
# Out:
#                        Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  \
# Variety
# Ambiance                     9.4         261              16.0          4.00
# Blood Orange                10.0         300               8.5          4.10
# California Valencia          8.5         220              12.0          3.60
# Cara Cara                    9.9         297              14.7          4.40
# Clementine                   9.4         299              16.0          4.30
# Clementine (Seedless)        6.7         140              14.0          3.00
# Hamlin                       8.5         220              11.5          3.40
# Honey Tangerine              9.3         243              14.2          3.72
# Jaffa                        8.1         292              14.0          3.98
# Midsweet (Hybrid)            8.9         240               9.5          3.80
# Minneola (Hybrid)            9.7         280              14.3          4.30
# ...
