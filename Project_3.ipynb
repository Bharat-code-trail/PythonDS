# %% [markdown]
# # Title:Social Media Sentiments Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science Project /sentimentdataset.csv')

# %% [markdown]
# ## **Basic Analysis**

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
df.shape
# Out:
# (732, 15)

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8
# ...

# %%
sns.countplot(df['Sentiment'])
# Out:
# <Axes: xlabel='count', ylabel='Sentiment'>

# %%
sns.lineplot(x='Platform', y='Sentiment', data=df)
# Out:
# <Axes: xlabel='Platform', ylabel='Sentiment'>

# %%
sent = df['Sentiment'].value_counts()
sent
# Out:
# Sentiment
# Positive           44
# Joy                42
# Excitement         32
# Neutral            14
# Contentment        14
#                    ..
# Adrenaline          1
# Harmony             1
# ArtisticBurst       1
# Radiance            1
# Elegance            1
# Name: count, Length: 279, dtype: int64

# %% [markdown]
# ### 1) What is the overall distribution of sentiments (positive, negative, neutral) across the posts?

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive           44
# Joy                42
# Excitement         32
# Neutral            14
# Contentment        14
#                    ..
# Adrenaline          1
# Harmony             1
# ArtisticBurst       1
# Radiance            1
# Elegance            1
# Name: count, Length: 279, dtype: int64

# %%
s_c = ['Positive', 'Negitive', 'Neutral']
f_c = df['Sentiment'][df['Sentiment'].isin(s_c)].value_counts()
print(f_c)
# Out:
# Series([], Name: count, dtype: int64)

# %%
sentiment_counts = df['Sentiment'].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(x=sentiment_counts.index[:10], y=sentiment_counts.values[:10], palette="coolwarm")
plt.xticks(rotation=45)
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.title("Top 10 Sentiment Distribution")
plt.show()

# %% [markdown]
# ### **2.)Which platform generates the most engagement in terms of likes and retweets?**

# %%
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
#
#              Timestamp            User    Platform  \
# 0  2023-01-15 12:30:00   User123         Twitter
# 1  2023-01-15 08:45:00   CommuterX       Twitter
#
#                                      Hashtags  Retweets  Likes     Country  \
# 0   #Nature #Park                                  15.0   30.0   USA
# 1   #Traffic #Morning                               5.0   10.0   Canada
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')

# %%
sns.barplot(x='Platform', y='Likes', data=df)
# Out:
# <Axes: xlabel='Platform', ylabel='Likes'>

# %%
sns.barplot(x='Platform', y='Retweets', data=df)
# Out:
# <Axes: xlabel='Platform', ylabel='Retweets'>

# %% [markdown]
# ## 3.)Which users have the highest average engagement (likes and retweets per post)?

# %%
sns.barplot(x='Platform', y='Likes', data=df)
# Out:
# <Axes: xlabel='Platform', ylabel='Likes'>

# %%
sns.barplot(x='User', y='Retweets', data=df)
# Out:
# <Axes: xlabel='User', ylabel='Retweets'>

# %%
u_avg = df.groupby('User')[['Likes', 'Retweets']].mean()
u_avg
# Out:
#                         Likes  Retweets
# User
# AbyssOfTime              45.0      22.0
# AcceptanceSeeker         30.0      15.0
# AdeleConcertGoer         80.0      40.0
# AdeleMelodyTearjerker    60.0      30.0
# AdventureAwaits          40.0      20.0
# ...                       ...       ...
# YearbookExplorer         25.0      12.0
# ZenLifestyle             30.0      15.0
# ZenMaster                30.0      15.0
# ZenMaster2               35.0      18.0
# ZenSeeker                70.0      35.0
#
# [685 rows x 2 columns]

# %%
u_avg = u_avg.sort_values(by='Likes', ascending=True)
u_avg
# Out:
#                         Likes  Retweets
# User
# CommuterX                10.0       5.0
# StrugglingSoul           10.0       5.0
# WellnessCheck            15.0       7.0
# DisgustedHeart           15.0       7.0
# SelfDoubt                15.0       8.0
# ...                       ...       ...
# SunshineDancer           80.0      40.0
# CultureEnthusiast        80.0      40.0
# AdeleConcertGoer         80.0      40.0
# Bookworm                 80.0      40.0
# BieberDanceEnthusiast    80.0      40.0
#
# [685 rows x 2 columns]
