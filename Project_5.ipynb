# %% [markdown]
# # Title: Australia Car Market Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science Project /cars_info.csv')

# %% [markdown]
# # Basic Analysis

# %%
df
# Out:
#              ID                                               Name   Price  \
# 0      11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1      12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2      12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3      12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4      12363884                       2016 Holden Cruze CD JH MY16   15990
# ...         ...                                                ...     ...
# 17043  12852453                 2003 Holden Commodore Executive VY    4499
# 17044  12852460                        2008 Toyota Yaris YR NCP90R    4999
# 17045  12852462               2002 Holden Jackaroo SE LWB (4X4) U8    7999
# 17046  12852463               2016 Hyundai I30 Active GD4 Series 2   14000
# 17047  12852464              2005 Toyota RAV4 Cruiser (4X4) ACA23R    5999
#
# ...

# %%
df.head(2)
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
#
#            Brand  Model               Variant    Series  Year  Kilometers  \
# 0         Toyota  Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz      V  250 D Avantgarde MWB  447 MY21  2021          19
#
#     Type    Gearbox             Fuel         Status    CC  Color  \
# 0  Wagon  Automatic  Unleaded Petrol           Used  2362   Grey
# 1  Wagon  Automatic           Diesel   New In Stock  2143  Black
#
#    Seating Capacity
# 0                 5
# 1                 7

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Price', 'Brand', 'Model', 'Variant', 'Series', 'Year',
#        'Kilometers', 'Type', 'Gearbox', 'Fuel', 'Status', 'CC', 'Color',
#        'Seating Capacity'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                  0
# Name                0
# Price               0
# Brand               0
# Model               0
# Variant             0
# Series              0
# Year                0
# Kilometers          0
# Type                0
# Gearbox             0
# Fuel                0
# Status              0
# CC                  0
# Color               0
# Seating Capacity    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Price', 'Brand', 'Model', 'Variant', 'Series', 'Year',
#        'Kilometers', 'Type', 'Gearbox', 'Fuel', 'Status', 'CC', 'Color',
#        'Seating Capacity'],
#       dtype='object')

# %%
sns.barplot(x='Brand',y='Price',data=df)
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
df.head(3)
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
#
#            Brand    Model               Variant    Series  Year  Kilometers  \
# 0         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 2  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
#
#     Type    Gearbox             Fuel         Status    CC  Color  \
# 0  Wagon  Automatic  Unleaded Petrol           Used  2362   Grey
# 1  Wagon  Automatic           Diesel   New In Stock  2143  Black
# 2  Wagon  Automatic           Diesel   New In Stock  2143  Black
#
#    Seating Capacity
# 0                 5
# 1                 7
# 2                 8

# %%
cars = df.groupby('Brand')['Price']

# %%
cars

# %%
sns.barplot(x='Status',y='Price',hue='Gearbox',data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Price'>

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(df['Kilometers'])
# Out:
# <Axes: xlabel='Kilometers', ylabel='Count'>

# %%
sns.countplot(df['Gearbox'])
# Out:
# <Axes: xlabel='count', ylabel='Gearbox'>

# %% [markdown]
# # Project Questions:

# %% [markdown]
# ### 1) What is the average price of cars across different brands, and which brands have the highest and lowest average prices?

# %%
df.groupby('Brand')['Price'].mean().sort_values(ascending=False)
# Out:
# Brand
# Lamborghini        452923.333333
# Aston Martin       235120.000000
# Bentley            181405.428571
# Porsche            153987.835165
# Chevrolet          145833.857143
# Ram                105055.956522
# FPV                 91490.000000
# Maserati            84859.750000
# HSV                 74036.162162
# Genesis             64888.000000
# Land Rover          64485.186813
# Mercedes-Benz       63490.852800
# Cupra               62334.200000
# Jaguar              61976.394737
# BMW                 56373.000000
# Iveco               52990.000000
# Audi                52605.027027
# Volvo               52159.484472
# Lexus               50281.566667
# Alfa Romeo          49282.545455
# Hino                46500.000000
# Isuzu               42962.951311
# Toyota              40719.680997
# Jeep                39098.102902
# GWM                 38250.793103
# Volkswagen          38100.763494
# Skoda               37865.675000
# LDV                 37798.696721
# ...

# %%
df.groupby('Brand')['Price'].max()
# Out:
# Brand
# Abarth              39500
# Alfa Romeo         105830
# Aston Martin       295750
# Audi               299990
# BMW                314988
# Bentley            299980
# Chery               12500
# Chevrolet          170000
# Chrysler            93990
# Citroen             58880
# Cupra               65989
# Dodge               18800
# FPV                139990
# Fiat                54990
# Ford               134705
# Foton               23990
# GWM                 45990
# Genesis             64888
# Great Wall          19990
# HSV                132490
# Haval               43990
# Hino                46500
# Holden             149990
# Honda               63990
# Hyundai            284888
# Infiniti            58000
# Isuzu               92500
# Iveco               52990
# Jaguar             171888
# Jeep               134990
# Kia                 83700
# LDV                 51490
# Lamborghini        479880
# Land Rover         199880
# Lexus              265980
# ...

# %% [markdown]
# ###2) How does the condition of a car (Status) affect its price?

# %%
df.groupby('Status')['Price'].mean()
# Out:
# Status
# Demo            67307.576227
# New In Stock    55703.207283
# Used            35638.707250
# Name: Price, dtype: float64

# %% [markdown]
# ### 3) Is there a correlation between mileage (Kilometers) and the price of a car?

# %%
df[['Kilometers', 'Price']].corr()
# Out:
#             Kilometers    Price
# Kilometers     1.00000 -0.44749
# Price         -0.44749  1.00000

# %% [markdown]
# ### 4) How does engine capacity (CC) relate to car price and mileage?

# %%
df.groupby('CC')[['Price','Kilometers']].mean().sort_values(by='Price',ascending=False)
# Out:
#               Price     Kilometers
# CC
# 3745  579900.000000   26120.000000
# 3996  392883.285714   13563.785714
# 5204  358540.000000   18110.666667
# 2981  290690.000000   21427.400000
# 3445  265980.000000    8902.000000
# ...             ...            ...
# 1948    4000.000000  237602.000000
# 2164    3648.500000  266155.250000
# 1341    3500.000000  204000.000000
# 1323    2990.000000  117932.000000
# 2606    2300.000000  263928.000000
#
# [305 rows x 2 columns]
